# %% [markdown]
# # Linear Regression Model
#
# Trained and tested a linear regression model to predict GDP from a set of 30+ features available in the GDP DataFrame

# %%
# Run the BEA base Jupyter Notebook

# %run BEA_Base_For_ML_Model.ipynb
# Out:
# BEA_Base_For_ML_Model completed - gdp_df ready for use

# %%
# Run the Treasury base Jupyter Notebook

# %run Treasury_Rates_Base_For_ML.ipynb
# Out:
# Treasury_Rates_Base_For_ML completed. treasury_df is ready for use

# %%
# Import libraries

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import math

# %%
# View the GDP dataframe

gdp_df.head()
# Out:
# Key Metrics Year-Qtr  Gross domestic product  \
# 0             1959Q1                 510.330
# 1             1959Q2                 522.653
# 2             1959Q3                 525.034
# 3             1959Q4                 528.600
# 4             1960Q1                 542.648
#
# Key Metrics  Personal consumption expenditures    Goods  Durable goods  \
# 0                                      309.449  169.723         43.649
# 1                                      315.505  172.617         45.465
# 2                                      320.725  174.524         46.336
# 3                                      322.842  173.564         44.103
# 4                                      326.364  175.060         45.455
#
# Key Metrics  Motor vehicles and parts  \
# 0                              18.090
# 1                              19.335
# 2                              20.073
# 3                              17.658
# 4                              19.343
#
# Key Metrics  Furnishings and durable household equipment  \
# 0                                                 15.143
# 1                                                 15.548
# 2                                                 15.647
# 3                                                 15.733
# 4                                                 15.522
#
# Key Metrics  Recreational goods and vehicles  Other durable goods  \
# 0                                      6.290                4.125
# 1                                      6.374                4.208
# 2                                      6.392                4.224
# 3                                      6.420                4.293
# 4                                      6.359                4.232
#
# Key Metrics  Nondurable goods  ...  \
# 0                     126.074  ...
# 1                     127.152  ...
# 2                     128.188  ...
# 3                     129.461  ...
# 4                     129.605  ...
#
# Key Metrics  Fed- National Defense - Consumption expenditures  \
# 0                                                      42.349
# 1                                                      41.394
# 2                                                      42.051
# 3                                                      42.233
# 4                                                      41.592
#
# Key Metrics  Fed- National Defense - Gross Investment  Nondefense  \
# 0                                              18.787      11.230
# 1                                              18.895      13.290
# 2                                              19.347      13.134
# 3                                              18.722      12.880
# 4                                              18.432      10.957
#
# Key Metrics  Fed - Nondefense - Consumption expenditures  \
# 0                                                  8.456
# 1                                                 10.441
# 2                                                 10.339
# 3                                                  9.942
# 4                                                  7.822
#
# Key Metrics  Fed - Nondefense - Gross Investment  State and local  \
# 0                                          2.774           44.829
# 1                                          2.849           44.955
# 2                                          2.795           44.960
# 3                                          2.938           44.772
# 4                                          3.135           45.970
#
# Key Metrics  State and local - Consumption expenditures  \
# 0                                                30.172
# 1                                                30.541
# 2                                                30.964
# 3                                                31.494
# 4                                                32.436
#
# Key Metrics  State and local - Gross Investment  GDP_Growth  Is_Recession
# 0                                        14.656    0.000000          True
# 1                                        14.414    0.024147         False
# 2                                        13.996    0.004556         False
# 3                                        13.278    0.006792         False
# 4                                        13.534    0.026576         False
#
# [5 rows x 65 columns]

# %%
# View the Treasury dataframe

treasury_df.head()
# Out:
#   Year-Qtr  10-2 Rate Diff  10-1 Rate Diff
# 0   1959Q1             0.0        0.486667
# 1   1959Q2             0.0        0.340000
# 2   1959Q3             0.0       -0.100000
# 3   1959Q4             0.0       -0.333333
# 4   1960Q1             0.0       -0.083333

# %%
# Merge GDP DF and Treasury DF
gdp_df = pd.merge(gdp_df, treasury_df, on = "Year-Qtr")

# %%
# View the merged DataFrame
gdp_df.head()
# Out:
#   Year-Qtr  Gross domestic product  Personal consumption expenditures  \
# 0   1959Q1                 510.330                            309.449
# 1   1959Q2                 522.653                            315.505
# 2   1959Q3                 525.034                            320.725
# 3   1959Q4                 528.600                            322.842
# 4   1960Q1                 542.648                            326.364
#
#      Goods  Durable goods  Motor vehicles and parts  \
# 0  169.723         43.649                    18.090
# 1  172.617         45.465                    19.335
# 2  174.524         46.336                    20.073
# 3  173.564         44.103                    17.658
# 4  175.060         45.455                    19.343
#
#    Furnishings and durable household equipment  \
# 0                                       15.143
# 1                                       15.548
# 2                                       15.647
# 3                                       15.733
# 4                                       15.522
#
#    Recreational goods and vehicles  Other durable goods  Nondurable goods  \
# 0                            6.290                4.125           126.074
# 1                            6.374                4.208           127.152
# 2                            6.392                4.224           128.188
# 3                            6.420                4.293           129.461
# 4                            6.359                4.232           129.605
#
#    ...  Nondefense  Fed - Nondefense - Consumption expenditures  \
# 0  ...      11.230                                        8.456
# 1  ...      13.290                                       10.441
# 2  ...      13.134                                       10.339
# 3  ...      12.880                                        9.942
# 4  ...      10.957                                        7.822
#
#    Fed - Nondefense - Gross Investment  State and local  \
# 0                                2.774           44.829
# 1                                2.849           44.955
# 2                                2.795           44.960
# 3                                2.938           44.772
# 4                                3.135           45.970
#
#    State and local - Consumption expenditures  \
# 0                                      30.172
# 1                                      30.541
# 2                                      30.964
# 3                                      31.494
# 4                                      32.436
#
#    State and local - Gross Investment  GDP_Growth  Is_Recession  \
# 0                              14.656    0.000000          True
# 1                              14.414    0.024147         False
# 2                              13.996    0.004556         False
# 3                              13.278    0.006792         False
# 4                              13.534    0.026576         False
#
#    10-2 Rate Diff  10-1 Rate Diff
# 0             0.0        0.486667
# 1             0.0        0.340000
# 2             0.0       -0.100000
# 3             0.0       -0.333333
# 4             0.0       -0.083333
#
# [5 rows x 67 columns]

# %%
# Multiple GDP Growth by 100 to see the percentage value
gdp_df["GDP_Growth"] = gdp_df["GDP_Growth"] * 100

# %%
# Define Features to predict on

X = gdp_df[['Housing and utilities',
            'Health care',
            'Transportation services',
            'Recreation services',
            'Food services and accommodations',
            'Financial services and insurance',
            'Other services',
            'Final Cons Expenditure nonprofit',
            'Motor vehicles and parts',
            'Furnishings and durable household equipment',
            'Recreational goods and vehicles',
            'Other durable goods',
            'Food and beverages (off-premises cons)',
            'Clothing and footwear', 
            'Gasoline and other energy goods',
            'Other nondurable goods',
            'Change in private inventories',
            'Structures',
            'Equipment',
            'Intellectual property products',
            'Information processing equipment',
            'Industrial equipment',
            'Transportation equipment',
            'Other equipment',
            'Computers and peripheral equipment',
            'Other',
            'Software',
            'Research and development',
            'Entertainment, literary, and artistic originals',
            'Federal',
            'State and local'
           ]]

# %%
# Scale the X Values
X_Scaled = StandardScaler().fit_transform(X)

# %%
# Define the target variable

y = gdp_df["Gross domestic product"]

# %%
# Split the test and train datasets

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create the Linear Regression model

model = LinearRegression()

# %%
# Fit the model

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict values using the model

predicted_y_values = model.predict(X_test)

# %%
# Score the model

model.score(X_test, y_test)
# Out:
# 0.9999786048349719

# %%
# Calculate Mean Squared Error
mse=mean_squared_error(y_test, predicted_y_values)

print(mse)
# Out:
# 1073.631502177715
